# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
# change python directory to /home/gmh4/projects/CompLab/comp-lab-class
os.chdir('/home/jh8862/theory-lab/comp-lab-2023/Week13/Analysis')

# %%
step, time, KE, temp, PE, ConsQ, usedTime = np.loadtxt("../Outputs/NPT-1.ener", comments=["#"], unpack=True)

# %%
plt.plot(time, PE)
plt.title("NPT Potential Energy")
plt.xlabel("Time (fs)")
plt.ylabel("Potential E (au)")
plt.savefig("../Figures/NPT_PEvtime.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
step, time, KE, temp, PE, ConsQ, usedTime = np.loadtxt("../Outputs/NVT-1.ener", comments=["#"], unpack=True)

# %%
plt.plot(time, PE)
plt.title("NVT Potential Energy")
plt.xlabel("Time (fs)")
plt.ylabel("Potential E (au)")
plt.savefig("../Figures/NVT_PEvtime.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
step, time, KE, temp, PE, ConsQ, usedTime = np.loadtxt("../Outputs/monitor/MONITOR-1.ener", comments=["#"], unpack=True)

# %%
plt.plot(time, PE)
plt.title("QM/MM Potential Energy")
plt.xlabel("Time (fs)")
plt.ylabel("Potential E (au)")
plt.savefig("../Figures/QMMM_PEvtime.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
step, time, KE, temp, PE, ConsQ, usedTime = np.loadtxt("../Outputs/metad1_initmonitor/METADYN-1.ener", comments=["#"], unpack=True)

# %%
plt.plot(time, PE)
plt.title("Metadyn1 Potential Energy")
plt.xlabel("Time (fs)")
plt.ylabel("Potential E (au)")
plt.savefig("../Figures/metadyn1_PEvtime.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
step, time, KE, temp, PE, ConsQ, usedTime = np.loadtxt("../Outputs/metad1_initmonitor_freqhills/METADYN-1.ener", comments=["#"], unpack=True)

# %%
plt.plot(time, PE)
plt.title("Metadyn1 Freq Hills Potential Energy")
plt.xlabel("Time (fs)")
plt.ylabel("Potential E (au)")
plt.savefig("../Figures/metadyn1_freqhills_PEvtime.png", dpi=300, bbox_inches="tight")
plt.show()
