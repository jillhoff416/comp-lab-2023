# %%
import numpy as np
import matplotlib.pyplot as plt
import mdtraj as md

# %%
import os
# change python directory 
os.chdir('/home/jh8862/theory-lab/comp-lab-2023/Week2/Analysis')

# %%
t, Potential, KineticE, TotalE, Temp, Pressure, Volume = np.loadtxt("../Data//1hz3_T310.run.25000000.energy.xvg", unpack = True, comments = ["#", "@"])

# %%
ylabels = ["Potential (kJ/mol)", "KineticE (kJ/mol)", "TotalE (kJ/mol)", "Temp (K)", "Pressure (bar)", "Volume (nm^3)"]
ynumbers = [Potential, KineticE, TotalE, Temp, Pressure, Volume]

for ylab, ynum in zip(ylabels, ynumbers):
    fig, ax = plt.subplots()
    ax.plot(t, ynum)

    ax.set(xlabel='time (ps)', ylabel=ylab)
    ax.grid()

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(t, Temp, linewidth=0.5)
ax2.plot(t, KineticE, color = "m", linewidth=0.5)

ax1.set(xlabel='time (ps)', ylabel="Temp (K)")
ax2.set(xlabel='time (ps)', ylabel="KineticE (kJ/mol)")
# Out:
# [Text(0.5, 0, 'time (ps)'), Text(0, 0.5, 'KineticE (kJ/mol)')]
